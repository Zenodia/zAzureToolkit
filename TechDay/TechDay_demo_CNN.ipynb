# %% [markdown]
# <h1><p><strong>Where did you get the data ?</strong> <strong></strong></p></h1>

# %%
# %%html
# <table cellspacing='2'>
# <td> <a href="https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia/home">link to kaggle dataset</a> <p>&nbsp;</p></td>
#     <tr>
#     <td> <img src="./pics/2class_pneumonia.jpg" alt="image" style="width: 1000px;"/> </td>
#     </tr>
# </table>
# Out:
# <table cellspacing='2'>
# <td> <a href="https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia/home">link to kaggle dataset</a> <p>&nbsp;</p></td>
#     <tr>
#     <td> <img src="./pics/2class_pneumonia.jpg" alt="image" style="width: 1000px;"/> </td>
#     </tr>
# </table>

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h1><p><strong>  Let's start building a model that can do the task</strong></p></h1><h2><strong><em>=>learn the label(=Pneumonia/Normal) per given image</em></strong></h2>

# %% [markdown]
# ## Step 1. Load pre-processed dataset

# %%
# to install Conx package go to https://github.com/Calysto/conx
# https://github.com/Calysto/conx-notebooks/tree/master/HowToRun#how-to-run-conx
# exercise for all deep learning : https://github.com/Calysto/conx-notebooks
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread
### load dataset 

X=np.load('X.npy')
y=np.load('Y.npy')
X.shape, y.shape
# Out:
# ((100, 150, 150, 3), (100,))

# %% [markdown]
# ## Step 2. Exploration - understanding features

# %%
import cv2
import numpy as np
import random
import matplotlib.pyplot as plt
import findcolor
# %matplotlib inline
rnn=random.randint(0,99)
classes={1:'Pneumonia',0:'Normal'}
sample_img=X[rnn]
#print ("---------------- original image **{}** -------------".format(y[rnn]))
#plt.imshow(sample_img)
#plt.title("sample image")
#plt.show()
"""
#print(sample_img.shape)
# Creating our 3 x 3 kernel
kernel_3x3 = np.ones((3, 3), np.float32) / 9

# We use the cv2.fitler2D to conovlve the kernal with an image 
blurred = cv2.filter2D(sample_img, -1, kernel_3x3)
#cv2.imshow('3x3 Kernel Blurring', blurred)
#cv2.waitKey(0)
#print(blurred.shape)
print("----------------- blur the image ----------------- ")
plt.imshow(blurred)
plt.title("image manipulation - blurred")
plt.show()

print("----------------- rotate and shrink the image ----------------- ")
### rotate image
height, width = sample_img.shape[:2]
# Divide by two to rototate the image around its centre
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), 30, .5)
rotated_image = cv2.warpAffine(sample_img, rotation_matrix, (width, height))
plt.imshow(rotated_image)
plt.title("image manipulation - rotate&shrink")
plt.show()
"""
print ("---------------- manipulate the image morphology -------------")

kernel = np.ones((2,2), np.uint8)
"""
# Now we erode
erosion = cv2.erode(sample_img, kernel, iterations = 1)
plt.imshow(erosion)
plt.title("image manipulateion -erosion")
plt.show()

dilation = cv2.dilate(sample_img, kernel, iterations = 1)
plt.imshow(dilation)
plt.title("image manipulateion -dilation")
plt.show()
"""
closing = cv2.morphologyEx(sample_img, cv2.MORPH_CLOSE, kernel)
plt.imshow(closing)
plt.title(" **{}** image manipulateion -morphology".format(classes[y[rnn]]))
plt.show()


plt.imsave('colors.jpg', np.squeeze(sample_img))
## find top 3 dominant color in a given image
print("------------ find dominate color within the **{}** image ------------".format(classes[y[rnn]]))
findcolor.find_color('colors.jpg')

im=cv2.imread('colors.jpg')

# Find Canny edges
edged = cv2.Canny(np.squeeze(sample_img), 197, 255)
#print(edged.shape)
img, contours, _ = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# Sort contours smallest to largest using reverse=False
sorted_contours = sorted(contours, key=cv2.contourArea, reverse=False) 
print("--------- image manipulation - find contours within the **{}** image ---------".format(classes[y[rnn]]))

cv2.drawContours(img, sorted_contours[0], -1, (0,255,0), 3)
plt.imshow(img)
plt.show()

print("-------- find background and mark background based on the color intensity of the image ------")
im = cv2.imread('colors.jpg')
gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow(thresh)
plt.title('background cadidates')
plt.show()

# noise removal
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 2)
# sure background area
sure_bg = cv2.dilate(opening,kernel,iterations=3)
# Finding sure foreground area
dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)
# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_fg)
#plt.imshow(sure_fg)
#plt.show()

# Marker labelling
ret, markers = cv2.connectedComponents(sure_fg)
# Add one to all labels so that sure background is not 0, but 1
markers = markers+1
# Now, mark the region of unknown with zero
markers[unknown==255] = 0
markers = cv2.watershed(im,markers)
im[markers == -1] = [255,0,0]
plt.imshow(im)
plt.title("mark background")
plt.show()
color_matters=False

if color_matters:
    print("------------------------  color manipulation filter red, green , blue channels ------------------ ")
    #### # Set global parameters
    RED = 0
    GREEN = 1
    BLUE = 2

    # Load the image
    img_color = cv2.imread("colors.jpg", flags=cv2.IMREAD_COLOR)
    print(img_color.shape)
    # Filter the image by desired color
    img_red = np.asarray([y[RED] for x in img_color for y in x]).reshape((img_color.shape[:2]))
    img_green= np.asarray([y[GREEN] for x in img_color for y in x]).reshape((img_color.shape[:2]))
    img_blue= np.asarray([y[BLUE] for x in img_color for y in x]).reshape((img_color.shape[:2]))
    f = plt.figure(figsize=(20,20))
    f.add_subplot(1,4, 1)
    plt.imshow(img_color)
    plt.title("contrast_img")
    f.add_subplot(1,4, 2)
    plt.imshow(img_red)
    plt.title("color_filter_red")
    f.add_subplot(1,4, 3)
    plt.imshow(img_green)
    plt.title("color_filter_green")
    f.add_subplot(1,4,4 )
    plt.imshow(img_blue)
    plt.title("color_filter_blue")
    plt.show()
# Out:
# ---------------- manipulate the image morphology -------------
# ------------ find dominate color within the **Pneumonia** image ------------
# color range start :0 end : 60.093333333333334
# color range start :60.093333333333334 end : 216.57333333333332
# color range start :216.57333333333332 end : 300.0
# --------- image manipulation - find contours within the **Pneumonia** image ---------
# -------- find background and mark background based on the color intensity of the image ------

# %% [markdown]
# ## Step 3. Choose a model Architecture -> CNN

# %%
#build the model
import conx as cx
net = cx.Network("CNN")
base_depth = 8
# Out:
# Using TensorFlow backend.
# ConX, version 3.7.4

# %%
# some initial params
tile_size=(150,150)
base_depth = 8
### build the network
net.add(cx.ImageLayer("input", tile_size, 3))
c2 = lambda i, j, act = "relu": cx.Conv2DLayer("conv_{}".format(i, j), j, (3, 3), padding='same', activation=act)
net.add(c2(0, base_depth))
net.add(c2(1, base_depth))
net.add(cx.MaxPool2DLayer("pool1", pool_size=(3, 3), dropout=0.25))
net.add(c2(2, 2*base_depth))
net.add(c2(3, 2*base_depth))
net.add(cx.MaxPool2DLayer("pool2", pool_size=(3, 3), dropout=0.25))
net.add(c2(4, 3*base_depth))
net.add(c2(5, 3*base_depth))
net.add(cx.MaxPool2DLayer("pool3", pool_size=(3, 3), dropout=0.25))
net.add(cx.FlattenLayer('flat_input'))
net.add(cx.Layer('hidden1', 300, activation='relu'))
net.add(cx.Layer('hidden2', 128, activation='relu'))
net.add(cx.Layer('output', 1, activation='sigmoid'))
# Out:
# 'output'

# %%
#### making connection
net.connect('input', 'conv_0')
net.connect('conv_0', 'conv_1')
net.connect('conv_1', 'pool1')
net.connect('pool1', 'conv_2')
net.connect('conv_2', 'conv_3')
net.connect('conv_3', 'pool2')
net.connect('pool2', 'conv_4')
net.connect('conv_4', 'conv_5')
net.connect('conv_5', 'pool3')
net.connect('pool3', 'flat_input')
net.connect('flat_input', 'hidden1')
net.connect('hidden1', 'hidden2')
net.connect('hidden2', 'output')

# %%
net.compile(error="binary_crossentropy", optimizer="adam")
# Out:
# WARNING: you are using a crossentropy error measure
#          but not using the 'softmax' activation function on layer 'output'

# %%
# load the pre-trained model
net.load('saved_model')
# Out:
# WARNING: you are using a crossentropy error measure
#          but not using the 'softmax' activation function on layer 'output'

# %%
net.picture(X[rnn], dynamic = True, rotate = True, show_targets = True, scale = 1.25)
# Out:
# <svg id='CNN' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' image-rendering="pixelated" width="1000.0px" height="129.62962962962962px">
#  <g  transform="rotate(90) translate(0 -1000.0)" >
#   <svg viewBox="0 0 350 2700" width="129.62962962962962px" height="1000.0px">
#     <defs>
#         <marker id="arrow" markerWidth="10" markerHeight="10" refX="9" refY="3" orient="auto" markerUnits="strokeWidth">
#           <path d="M0,0 L0,6 L9,3 z" fill="black" />
#         </marker>
#     </defs><rect x="149.0" y="24" width="52" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_output_targets_1" class="CNN_output_targets" x="150.0" y="25" height="50" width="50" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output (output)
#  output range: (0, 1)
#  shape = (1,)
#  Keras class = Dense
#  activation = sigmoid</title><text x="213.0" y="52.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 213.0 52.0) translate(2)" >targets</text><line x1="87.5" y1="80" x2="262.5" y2="80" stroke="green" stroke-width="2"><title></title></line><rect x="149.0" y="84" width="52" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_output-rotated_1" class="CNN_output-rotated" x="150.0" y="85" height="50" width="50" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output (output)
#  output range: (0, 1)
#  shape = (1,)
#  Keras class = Dense
#  activation = sigmoid</title><text x="213.0" y="112.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 213.0 112.0) translate(2)" >output</text><line x1="175.0" y1="164" x2="175.0" y2="137" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from hidden2 to output
#  output_3/kernel:0 has shape (128, 1)
#  output_3/bias:0 has shape (1,)</title></line><rect x="74.0" y="164" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_hidden2-rotated_2" class="CNN_hidden2-rotated" x="75.0" y="165" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden2 (hidden)
#  output range: (0, +Infinity)
#  shape = (128,)
#  Keras class = Dense
#  activation = relu</title><text x="288.0" y="192.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 192.0) translate(2)" >hidden2</text><line x1="175.0" y1="244" x2="175.0" y2="217" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from hidden1 to hidden2
#  hidden2_3/kernel:0 has shape (300, 128)
#  hidden2_3/bias:0 has shape (128,)</title></line><rect x="74.0" y="244" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_hidden1-rotated_3" class="CNN_hidden1-rotated" x="75.0" y="245" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden1 (hidden)
#  output range: (0, +Infinity)
#  shape = (300,)
#  Keras class = Dense
#  activation = relu</title><text x="288.0" y="272.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 272.0) translate(2)" >hidden1</text><line x1="175.0" y1="324" x2="175.0" y2="297" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from flat_input to hidden1
#  hidden1_2/kernel:0 has shape (600, 300)
#  hidden1_2/bias:0 has shape (300,)</title></line><rect x="74.0" y="324" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_flat_input-rotated_4" class="CNN_flat_input-rotated" x="75.0" y="325" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: flat_input (hidden)
#  output range: (-Infinity, +Infinity)
#  Keras class = Flatten</title><text x="288.0" y="352.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 352.0) translate(2)" >flat_input</text><line x1="175.0" y1="404" x2="175.0" y2="377" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from pool3 to flat_input</title></line><rect x="74.0" y="404" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_pool3-rotated_5" class="CNN_pool3-rotated" x="75.0" y="405" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: pool3 (hidden)
#  output range: (-Infinity, +Infinity)
#  dropout = 0.25
#  Keras class = MaxPooling2D
#  pool_size = (3, 3)</title><text x="288.0" y="507.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 507.0) translate(2)" >pool3</text><text x="88.0" y="390" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 88.0 390) translate(2)" >24</text><text x="273.0" y="620" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 273.0 620) translate(2)" >0</text><text x="62.0" y="410" font-family="monospace" font-size="24.0" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 62.0 410) translate(2)" >&#10683;</text><line x1="175.0" y1="634" x2="175.0" y2="607" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from conv_5 to pool3</title></line><rect x="74.0" y="634" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_conv_5-rotated_6" class="CNN_conv_5-rotated" x="75.0" y="635" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: conv_5 (hidden)
#  output range: (0, +Infinity)
#  Keras class = Conv2D
#  padding = same
#  activation = relu</title><text x="288.0" y="737.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 737.0) translate(2)" >conv_5</text><text x="88.0" y="620" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 88.0 620) translate(2)" >24</text><text x="273.0" y="850" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 273.0 850) translate(2)" >0</text><line x1="175.0" y1="864" x2="175.0" y2="837" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from conv_4 to conv_5
#  conv_5_1/kernel:0 has shape (3, 3, 24, 24)
#  conv_5_1/bias:0 has shape (24,)</title></line><rect x="74.0" y="864" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="CNN_conv_4-rotated_7" class="CNN_conv_4-rotated" x="75.0" y="865" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: conv_4 (hidden)
#  output range: (0, +Infinity)
#  Keras class = Conv2D
#  padding = same
#  activation = relu</title><text x="288.0" y="967.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 967.0) translate(2)" >conv_4</text><text x="88.0" y="850" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 88.0 850) translate(2)" >24</text><text x="273.0" y="1080" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 273.0 1080) translate(2)" >0</text><line x1

# %%
net.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 150, 150, 3)       0
# _________________________________________________________________
# conv_0 (Conv2D)              (None, 150, 150, 8)       224
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 150, 150, 8)       584
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 50, 50, 8)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 50, 8)         0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 50, 50, 16)        1168
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 50, 50, 16)        2320
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 16, 16, 24)        3480
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 16, 16, 24)        5208
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 5, 5, 24)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 24)          0
# _________________________________________________________________
# flat_input (Flatten)         (None, 600)               0
# _________________________________________________________________
# hidden1 (Dense)              (None, 300)               180300
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               38528
# _________________________________________________________________
# output (Dense)               (None, 1)                 129
# =================================================================
# Total params: 231,941
# Trainable params: 231,941
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 4. Split dataset into Train vs Validation sets to train and evaluate the model respectively.

# %%
### randomly shuffle the data
import numpy as np
from itertools import permutations
import random
ls=[i for i in range(len(y))]
idxes=random.shuffle(ls)
ip_pairs=[(X[i],y[i].reshape(1)) for i in ls]
plt.imshow(ip_pairs[0][0])
plt.title(classes[int(ip_pairs[0][1])])
plt.show()

# %%
# makeing sure the classes is balanced
np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([50, 50], dtype=int64))

# %%
net.dataset.clear()

net.dataset.append(ip_pairs)
net.dataset.split(0.25) # split into training set 75% and validataion set 25%

# %% [markdown]
# ## Step 5. Evaluate the model result

# %%
net.train(epochs=10, record=True, shuffle=True, batch_size=10, accuracy=0.95)
# Out:
# Evaluating initial validation metrics...
# No training required: accuracy already to desired value
# Training dataset status:
#        |  Training |  Training |  Validate |  Validate
# Epochs |     Error |  Accuracy |     Error |  Accuracy
# ------ | --------- | --------- | --------- | ---------
# #   44 |   0.04637 |   0.96000 |   0.27108 |   0.88000

# %%
net.plot('acc'), net.plot('loss')
# Out:
# (None, None)

# %%
net.evaluate()
# Out:
# {'acc': 0.93333333730697632,
#  'loss': 0.030273852646350862,
#  'val_acc': 0.92000001668930054,
#  'val_loss': 0.242605060338974}

# %%
net.picture(X[0], dynamic = True, rotate = True, show_targets = True,class_id=1, scale =1.25)
# Out:
# <svg id='CNN' xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' image-rendering="pixelated" width="1000.0px" height="129.62962962962962px">
#  <g  transform="rotate(90) translate(0 -1000.0)" >
#   <svg viewBox="0 0 350 2700" width="129.62962962962962px" height="1000.0px">
#     <defs>
#         <marker id="arrow" markerWidth="10" markerHeight="10" refX="9" refY="3" orient="auto" markerUnits="strokeWidth">
#           <path d="M0,0 L0,6 L9,3 z" fill="black" />
#         </marker>
#     </defs><rect x="149.0" y="24" width="52" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="1_output_targets_15" class="1_output_targets" x="150.0" y="25" height="50" width="50" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output (output)
#  output range: (0, 1)
#  shape = (1,)
#  Keras class = Dense
#  activation = sigmoid</title><text x="213.0" y="52.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 213.0 52.0) translate(2)" >targets</text><line x1="87.5" y1="80" x2="262.5" y2="80" stroke="green" stroke-width="2"><title></title></line><rect x="149.0" y="84" width="52" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="1_output-rotated_15" class="1_output-rotated" x="150.0" y="85" height="50" width="50" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: output (output)
#  output range: (0, 1)
#  shape = (1,)
#  Keras class = Dense
#  activation = sigmoid</title><text x="213.0" y="112.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 213.0 112.0) translate(2)" >output</text><line x1="175.0" y1="164" x2="175.0" y2="137" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from hidden2 to output
#  output_3/kernel:0 has shape (128, 1)
#  output_3/bias:0 has shape (1,)</title></line><rect x="74.0" y="164" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="1_hidden2-rotated_16" class="1_hidden2-rotated" x="75.0" y="165" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden2 (hidden)
#  output range: (0, +Infinity)
#  shape = (128,)
#  Keras class = Dense
#  activation = relu</title><text x="288.0" y="192.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 192.0) translate(2)" >hidden2</text><line x1="175.0" y1="244" x2="175.0" y2="217" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from hidden1 to hidden2
#  hidden2_3/kernel:0 has shape (300, 128)
#  hidden2_3/bias:0 has shape (128,)</title></line><rect x="74.0" y="244" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="1_hidden1-rotated_17" class="1_hidden1-rotated" x="75.0" y="245" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: hidden1 (hidden)
#  output range: (0, +Infinity)
#  shape = (300,)
#  Keras class = Dense
#  activation = relu</title><text x="288.0" y="272.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 272.0) translate(2)" >hidden1</text><line x1="175.0" y1="324" x2="175.0" y2="297" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from flat_input to hidden1
#  hidden1_2/kernel:0 has shape (600, 300)
#  hidden1_2/bias:0 has shape (300,)</title></line><rect x="74.0" y="324" width="202" height="52" style="fill:none;stroke:black;stroke-width:2"/><image id="1_flat_input-rotated_18" class="1_flat_input-rotated" x="75.0" y="325" height="50" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: flat_input (hidden)
#  output range: (-Infinity, +Infinity)
#  Keras class = Flatten</title><text x="288.0" y="352.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 352.0) translate(2)" >flat_input</text><line x1="175.0" y1="404" x2="175.0" y2="377" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from pool3 to flat_input</title></line><rect x="74.0" y="404" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="1_pool3-rotated_19" class="1_pool3-rotated" x="75.0" y="405" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: pool3 (hidden)
#  output range: (-Infinity, +Infinity)
#  dropout = 0.25
#  Keras class = MaxPooling2D
#  pool_size = (3, 3)</title><text x="288.0" y="507.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 507.0) translate(2)" >pool3</text><text x="88.0" y="390" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 88.0 390) translate(2)" >24</text><text x="273.0" y="620" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 273.0 620) translate(2)" >0</text><text x="62.0" y="410" font-family="monospace" font-size="24.0" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 62.0 410) translate(2)" >&#10683;</text><line x1="175.0" y1="634" x2="175.0" y2="607" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from conv_5 to pool3</title></line><rect x="74.0" y="634" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="1_conv_5-rotated_20" class="1_conv_5-rotated" x="75.0" y="635" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: conv_5 (hidden)
#  output range: (0, +Infinity)
#  Keras class = Conv2D
#  padding = same
#  activation = relu</title><text x="288.0" y="737.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 737.0) translate(2)" >conv_5</text><text x="88.0" y="620" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 88.0 620) translate(2)" >24</text><text x="273.0" y="850" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 273.0 850) translate(2)" >0</text><line x1="175.0" y1="864" x2="175.0" y2="837" stroke="black" stroke-width="2" marker-end="url(#arrow)"><title>Weights from conv_4 to conv_5
#  conv_5_1/kernel:0 has shape (3, 3, 24, 24)
#  conv_5_1/bias:0 has shape (24,)</title></line><rect x="74.0" y="864" width="202" height="202" style="fill:none;stroke:black;stroke-width:2"/><image id="1_conv_4-rotated_21" class="1_conv_4-rotated" x="75.0" y="865" height="200" width="200" preserveAspectRatio="none" image-rendering="optimizeSpeed" xlink:href="data:image/gif;base64,..."><title>Layer: conv_4 (hidden)
#  output range: (0, +Infinity)
#  Keras class = Conv2D
#  padding = same
#  activation = relu</title><text x="288.0" y="967.0" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 288.0 967.0) translate(2)" >conv_4</text><text x="88.0" y="850" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 88.0 850) translate(2)" >24</text><text x="273.0" y="1080" font-family="monospace" font-size="12" text-anchor="middle" fill="black" alignment-baseline="central"  transform="rotate(-90 273.0 1080) translate(2)" >0</text><line x1="175.0" y1="1094" x2="1

# %%
net.dashboard()
# Out:
# Dashboard(children=(Accordion(children=(HBox(children=(VBox(children=(Select(description='Dataset:', index=1, …

# %% [markdown]
# ## (option) evaluate the result visually

# %%
net.movie(lambda net, epoch: net.propagate_to_image("conv_3", X[0], scale = 3), 
                'conv_3.gif', mp4 = False)
# Out:
# <img src="conv_3.gif"/>

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h1><p><strong>How to take this model to production </strong></p></h1><h2> <strong>Azure databrick architecture</strong></h2>

# %%
# %%html
# <table cellspacing='2'>
# <td> <a href="https://www.linkedin.com/pulse/transfer-learning-azure-databrick-deploy-web-service-zenodia-charpy">how to deploy model to Azure</a> <p>&nbsp;</p></td>
#     <tr>
#     <td> <img src="./pics/azure_databrick.jpg" alt="image" style="width: 1000px;"/> </td>
#     </tr>
# </table>
# Out:
# <table cellspacing='2'>
# <td> <a href="https://www.linkedin.com/pulse/transfer-learning-azure-databrick-deploy-web-service-zenodia-charpy">how to deploy model to Azure</a> <p>&nbsp;</p></td>
#     <tr>
#     <td> <img src="./pics/azure_databrick.jpg" alt="image" style="width: 1000px;"/> </td>
#     </tr>
# </table>
